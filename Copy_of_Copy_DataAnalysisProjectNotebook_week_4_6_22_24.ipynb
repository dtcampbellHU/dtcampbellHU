# %% [markdown]
# <a href="https://colab.research.google.com/github/dtcampbellHU/dtcampbellHU/blob/main-branch/Copy_of_Copy_DataAnalysisProjectNotebook_week_4_6_22_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1: Establish your Group and Identify Group Roles
# Hello Scholars and welcome to the Howard University Applied Data Science and Analytics Bootcamp. As part of your first week activities you have been assigned a group to collaborate for a data analytics project. The goal is to demonstrate how the skills you are learning contribute to the analysis of data and determine actionable insights. As you work through the document, there are comments to the right to help guide you. When they are completed you should click the blue checkmark and resolve them.
#
# In the first week of your group project you will identify the role of each of your group members, develop a research question, and identify a dataset you will use to answer the research question.

# %% [markdown]
# **Group Members:**
#
# *  Machine Learning Engineer:Tai Timmerman
# *  Data Scientist: Kayla McKenzie
# *  Business Analyst: Kritartha Karki
# *  Data Visualization Specialist: Lovelace Boafo
# *  Data Engineer: Dee Campbell
#
#
# **Problem Statements:**
# *  Age-associated Air Pollution Vulnerabilities
# *   Disparities in Environmental Health by geographic location
# *   Deviations in Cancer Risk by Gender
# *   Race and income disparities in total cancer risk
# *   Lifestyle Factors such as smoking, diet, and physical activity impact
# *  Total cancer risk in different demographic areas.
# *  Healthcare access
#
#
#
#
# **Dataset**: 2019_National_CancerRisk_by_tract_srcgrp.csv
#
#
#
# **Develop a Research Question:**
#
# How does the Total Cancer Risk per million fluctuate throughout distinct demographic categories, such as age, gender, and geographic location, based on comparative analysis of diversified datasets?

# %% [markdown]
# # Week 2: The Data Science Process
# The data science process consists of seven key steps. Each week we will complete another step of the process. The work we complete in class each week will structure the work you will complete on the group project. This week you will work on working with your dataset file, loading data into the python environment, and making a plan for data cleaning steps.

# %% [markdown]
# ## Data Collection:

# %% [markdown]
# Data collection begins with identifying a reliable and accurate data source and using tools to download the dataset for examination. The drive is mounted and imported to Colab, creating a link to the data source. Next, the necessary libraries are imported which contain pre-written code which perform specific tasks. Python has several libraries which are powerful tools from data analysis and visualization.
#
# Once the dataset are loaded and the libraries imported, the dataset can be read and the dataframe created. Now the data is checked and the data cleaning process begins.

# %% [markdown]
# ### Examine the dataset

# %% [markdown]
# Describe Methodology.
# Load the Dataset, check the data types, missing values, completeness of data, create a data dictionary.

# %%
# Load the Dataset
# Mount the Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import libraries

# %%
# Import the libraries, allow people to code faster; you can also google search for libraries that are relevant to your data
import numpy as np                  # Scientific Computing
import pandas as pd                 # Data Analysis
import matplotlib.pyplot as plt     # Plotting
import seaborn as sns               # Statistical Data Visualization

# Let's make sure pandas returns all the rows and columns for the dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Force pandas to display full numbers instead of scientific notation
# pd.options.display.float_format = '{:.0f}'.format

# Library to suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the dataset

# %%
# Read the dataset  /content/2019_National_CancerRisk_by_tract_srcgrp.csv
# /2019_National_CancerRisk_by_tract_srcgrp.csv
path = pd.read_csv("/content/2019_National_CancerRisk_by_tract_srcgrp.csv")
# Create the Dataframe
NatCanRisk = pd.DataFrame(path)

# %% [markdown]
# #### Understanding the Dataset
# - Checking first elements of the DataFrame with .head( ) method
# - After you run the code above, nothing will appear.
# - So you have to write df to see your data. But instead of seeing all the data, we are going to use the “.head( )” method to see the first five elements of the data.
# - Before you run the read_csv code, you can write df.head( ) below. So it’s going to be like this:

# %% [markdown]
# Inside the parentheses, we can write the number of elements that we want to see.
# If we leave it blank, it will show the first five elements.
# If we write 7 inside of the parentheses, it will show the first 7 elements of the dataframe.

# %%
# Display the first ten rows of the dataframe
# Syntax: DataFrame.head(qty)

NatCanRisk.head(10)
# Out:
#   State    EPA Region        County  FIPS       Tract  Population  \
# 0    US     Entire US     Entire US     0           0   312566557
# 1    AL  EPA Region 4  Entire State  1000  1000000000     4779636
# 2    AL  EPA Region 4       Autauga  1001  1001000000       54571
# 3    AL  EPA Region 4       Autauga  1001  1001020100        1912
# 4    AL  EPA Region 4       Autauga  1001  1001020200        2170
# 5    AL  EPA Region 4       Autauga  1001  1001020300        3373
# 6    AL  EPA Region 4       Autauga  1001  1001020400        4386
# 7    AL  EPA Region 4       Autauga  1001  1001020500       10766
# 8    AL  EPA Region 4       Autauga  1001  1001020600        3668
# 9    AL  EPA Region 4       Autauga  1001  1001020700        2891
#
#    Total Cancer Risk (per million)  \
# 0                               30
# 1                               30
# 2                               40
# 3                               40
# 4                               40
# ...

# %% [markdown]
# Checking last elements of the DataFrame with .tail() method
# There is also a method to see the see last n number of elements.
# The method is called .tail().
# The same rule is also applied here. If we leave the parentheses blank, it will be set as 5, if we write 7 inside of the parentheses, it will show the last 7 elements of the dataframe.

# %%
# Display the last ten rows of the dataframe
# Syntax: DataFrame.tail(qty)

NatCanRisk.tail(10)
# Out:
#       State    EPA Region      County   FIPS        Tract  Population  \
# 76716    VI  EPA Region 2  St. Thomas  78030  78030960300        4520
# 76717    VI  EPA Region 2  St. Thomas  78030  78030960400        4709
# 76718    VI  EPA Region 2  St. Thomas  78030  78030960500        5431
# 76719    VI  EPA Region 2  St. Thomas  78030  78030960600        3987
# 76720    VI  EPA Region 2  St. Thomas  78030  78030960700        3520
# 76721    VI  EPA Region 2  St. Thomas  78030  78030960800        4088
# 76722    VI  EPA Region 2  St. Thomas  78030  78030960900        4878
# 76723    VI  EPA Region 2  St. Thomas  78030  78030961000        5220
# 76724    VI  EPA Region 2  St. Thomas  78030  78030961100        4356
# 76725    VI  EPA Region 2  St. Thomas  78030  78030961200        2816
#
#        Total Cancer Risk (per million)  \
# 76716                               10
# 76717                               10
# 76718                               10
# ...

# %%
# display the dimensions of the data
# This is the number of rows and columns in the data
# Syntax: DataFrame.shape

NatCanRisk.shape
# Out:
# (76726, 45)

# %% [markdown]
# * State the shape of the dataframe :
#   - How many rows does the dataframe have?
#
#         The data frame has 76726 rows.
#
#   - How many columns does the dataframe have?
#
#         The data frame has 45 columns.
#   - What is the total number of datapoints expected in the dataset (rows x columns)?
#         The total number of data points in the data set is 3,452,670.

# %% [markdown]
# ### Data Types
# * The main data types in Pandas dataframes are `object`, `float`, `int64`, `bool` and `datetime64`. In order to understand each attribute of the data, it is always good to know the data type of each column.
#
# ##### `.info()` method
# * This method prints information about a DataFrame including the index `dtype` and column dtypes, non-null values and memory usage.

# %%
# Let's check the basic information about the dataset
# Syntax: DataFrame.info() Start making notes about why certain things are objects vs int and floats?

NatCanRisk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76726 entries, 0 to 76725
# Data columns (total 45 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   State                                                                 76726 non-null  object
#  1   EPA Region                                                            76726 non-null  object
#  2   County                                                                76726 non-null  object
#  3   FIPS                                                                  76726 non-null  int64
#  4   Tract                                                                 76726 non-null  int64
#  5   Population                                                            76726 non-null  int64
# ...

# %% [markdown]
# ### Observations of the Data Set
# In 500 words, describe the dataset. How many rows and columns are there? What are the data types? Based on the number of expected data points, and those listed by the `.info()` method, how many missing (null) values are there?
#
# **  There are 76726 rows and 45 columns. There are many data types represented by the data including int, float, and object. In each of the 45 columns has 76726 items which is expected. There are not any null values. The state, EPA region and county are objects which is expected. The other columns contain int and float because they are numerical values. These columns include different types of cancer risk per million. This appears to be a clean set of data from the EPA.**

# %% [markdown]
# **Insert summary:**

# %% [markdown]
# If there is missing data describe in 200 words, why the data is missing?
#
# **There is no missing data in this data set. In each of the 45 columns has 76726 items which is expected. There are not any null values.**

# %% [markdown]
# # Data Cleaning:

# %% [markdown]
# ### Headers Update and Map New Column
#
# >
# - To aid in analysis and visualization add a new columns as needed. For instance instead of an entire state name, add a column that has a two letter abbreviation for the state.
# - The list of headers requires standardization, these will be updated ensure uniformity.
# - Update ALL CAPS or all lowercase to the appropriate case. These can be updated to Title Case.

# %%
# Let's create a list of the columns in the dataset
# Use the variable = DataFrame.columns method

ListofColumnsCan = NatCanRisk.columns
ListofColumnsCan
# Out:
# Index(['State', 'EPA Region', 'County', 'FIPS', 'Tract', 'Population',
#        'Total Cancer Risk (per million)',
#        'PT-StationaryPoint Cancer Risk (per million)',
#        'OR-LightDuty-OffNetwork-Gas Cancer Risk (per million)',
#        'OR-LightDuty-OffNetwork-Diesel Cancer Risk (per million)',
#        'OR-HeavyDuty-OffNetwork-Gas Cancer Risk (per million)',
#        'OR-HeavyDuty-OffNetwork-Diesel Cancer Risk (per million)',
#        'OR-LightDuty-OnNetwork-Gas Cancer Risk (per million)',
#        'OR-LightDuty-OnNetwork-Diesel Cancer Risk (per million)',
#        'OR-HeavyDuty-OnNetwork-Gas Cancer Risk (per million)',
#        'OR-HeavyDuty-OnNetwork-Diesel Cancer Risk (per million)',
#        'OR-Refueling Cancer Risk (per million)',
#        'OR-HeavyDuty-Hoteling Cancer Risk (per million)',
#        'NR-Recreational-inc-PleasureCraft Cancer Risk (per million)',
#        'NR-Construction Cancer Risk (per million)',
# ...

# %%
# Let's Update the Headers for Syntax Consistency
# Syntax: df = df.rename(columns={'currentColumnName':'newColumnName', 'nextCurrentColumnName':'nextNewColumnName'})

NatCanRisk = NatCanRisk.rename(columns={'NR-CommercialLawnGarden Cancer Risk (per million)': 'NR-Commercial Lawn Garden Cancer Risk (per million)', 'NR-ResidentialLawnGarden Cancer Risk (per million)' : 'NR-Residential Lawn Garden Cancer Risk (per million)' , 'NP-SolventsCoatings Cancer Risk (per million)' : 'Solvents Coatings Cancer Risk' , 'NP-FuelCombustion_not_RWC Cancer Risk (per million)' : 'Fuel Combustion not RWC Cancer Risk', 'NP-ResidentialWoodCombustionRWC Cancer Risk (per million)' : 'Residential Wood Combustion', 'FIRE Cancer Risk (per million)' : 'Fire Cancer Risk' , 'BIOGENICS Cancer Risk (per million)' : 'Biogenics Cancer Risk', 'SECONDARY Cancer Risk (per million)': 'Secondary Cancer Risk', 'BACKGROUND Cancer Risk (per million)' : 'Background Cancer Risk', 'Total Cancer Risk (per million)' : 'Total Cancer Risk'})

# Let's view the new columns and update the variable
# Pass the columns to the variable: Use the variable = DataFrame.columns method
NanCanRiskRename=NatCanRisk.columns


# Call the variable to see the contents
NanCanRiskRename
# Out:
# Index(['State', 'EPA Region', 'County', 'FIPS', 'Tract', 'Population',
#        'Total Cancer Risk', 'PT-StationaryPoint Cancer Risk (per million)',
#        'OR-LightDuty-OffNetwork-Gas Cancer Risk (per million)',
#        'OR-LightDuty-OffNetwork-Diesel Cancer Risk (per million)',
#        'OR-HeavyDuty-OffNetwork-Gas Cancer Risk (per million)',
#        'OR-HeavyDuty-OffNetwork-Diesel Cancer Risk (per million)',
#        'OR-LightDuty-OnNetwork-Gas Cancer Risk (per million)',
#        'OR-LightDuty-OnNetwork-Diesel Cancer Risk (per million)',
#        'OR-HeavyDuty-OnNetwork-Gas Cancer Risk (per million)',
#        'OR-HeavyDuty-OnNetwork-Diesel Cancer Risk (per million)',
#        'OR-Refueling Cancer Risk (per million)',
#        'OR-HeavyDuty-Hoteling Cancer Risk (per million)',
#        'NR-Recreational-inc-PleasureCraft Cancer Risk (per million)',
#        'NR-Construction Cancer Risk (per million)',
#        'NR-Commercial Lawn Garden Cancer Risk (per million)',
# ...

# %% [markdown]
# **We can only update string text to Title case. Therefore, the only values that can be updated to Title case are EPA region, State, and county. I updated EPA region and County below. **

# %%
# Let's update the string text in headers to Title case.
# Syntax: df['column'].str.title()


NatCanRisk['EPA Region'] = NatCanRisk['EPA Region'].str.title()
NatCanRisk['County'] = NatCanRisk['County'].str.title()



# Let's See the results using the .head() method
# Syntax: DataFrame.head(qty)
NatCanRisk.head(10)
#NatCanRisk.tail(10)
# Out:
#   State    EPA Region        County  FIPS       Tract  Population  \
# 0    US     Entire Us     Entire Us     0           0   312566557
# 1    AL  Epa Region 4  Entire State  1000  1000000000     4779636
# 2    AL  Epa Region 4       Autauga  1001  1001000000       54571
# 3    AL  Epa Region 4       Autauga  1001  1001020100        1912
# 4    AL  Epa Region 4       Autauga  1001  1001020200        2170
# 5    AL  Epa Region 4       Autauga  1001  1001020300        3373
# 6    AL  Epa Region 4       Autauga  1001  1001020400        4386
# 7    AL  Epa Region 4       Autauga  1001  1001020500       10766
# 8    AL  Epa Region 4       Autauga  1001  1001020600        3668
# 9    AL  Epa Region 4       Autauga  1001  1001020700        2891
#
#    Total Cancer Risk  PT-StationaryPoint Cancer Risk (per million)  \
# 0                 30                                         1.596
# 1                 30                                         1.351
# ...

# %% [markdown]
# **We created a new column to add the commercial and residential risk of cancer per million from lawn/garden sources. We wanted to investigate the impact of lawn/garden toxin sources on total cancer risk. We can also see how the total lawn/garden rates are higher in differing states with different socioeconomic makeups.**

# %%
# Create (1) one new column in the dataframe based on a mathematical operation involving two existing columns.
# Explain why you created this new column.

NatCanRisk ['Total Lawn Garden']=NatCanRisk['NR-Commercial Lawn Garden Cancer Risk (per million)'] + NatCanRisk['NR-Residential Lawn Garden Cancer Risk (per million)']
NatCanRisk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76726 entries, 0 to 76725
# Data columns (total 46 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   State                                                                 76726 non-null  object
#  1   EPA Region                                                            76726 non-null  object
#  2   County                                                                76726 non-null  object
#  3   FIPS                                                                  76726 non-null  int64
#  4   Tract                                                                 76726 non-null  int64
#  5   Population                                                            76726 non-null  int64
# ...

# %% [markdown]
# We created a new column with the operation-
#
# NatCanRisk ['Total Lawn Garden']=NatCanRisk['NR-Commercial Lawn Garden Cancer Risk (per million)'] + NatCanRisk['NR-Residential Lawn Garden Cancer Risk (per million)']
# NatCanRisk.info().
#
# Therefore, we did not use the dictionary funtion.

# %%
# Let's create a new column
# The goal is to create a map function to apply the new information based on an existing column.
# Syntax: dictionaryName = ({key: value})



# Call the variable to see the contents

# %%
# Read the dictionary into the dataframe
# Syntax: df['NewColumnName'] = df['ColumnToMatch'].map(dictionaryName)


#Print the first 20 rows of the resulting DataFrame
# Syntax: DataFrame.head(qty)

# %% [markdown]
# ### Missing Values
# If we encounter with missing data, what we can do:
#
# - leave as is
# - drop them with `dropna()`
# - fill missing value with `fillna()`
# - fill missing values with test statistics like mean
# - One of the most common problems in data science is missing values.
# - To detect them, there is a beautiful method which is called `.isnull()`. With this method, we can get a boolean series (True or False).
# - When we add the `.sum()` we can get the total count of missing values.
#
#
# **There is no missing data in the dataframe. Therefore, there is no data to drop or fill in. The .isnull method shows that each of the columns have 0 null values. **

# %%
# Determine the number of missing values
# Syntax: DataFrame.isnull().sum()

NatCanRisk.isnull().sum()
# Out:
# State                                                                   0
# EPA Region                                                              0
# County                                                                  0
# FIPS                                                                    0
# Tract                                                                   0
# Population                                                              0
# Total Cancer Risk                                                       0
# PT-StationaryPoint Cancer Risk (per million)                            0
# OR-LightDuty-OffNetwork-Gas Cancer Risk (per million)                   0
# OR-LightDuty-OffNetwork-Diesel Cancer Risk (per million)                0
# OR-HeavyDuty-OffNetwork-Gas Cancer Risk (per million)                   0
# OR-HeavyDuty-OffNetwork-Diesel Cancer Risk (per million)                0
# OR-LightDuty-OnNetwork-Gas Cancer Risk (per million)                    0
# ...

# %% [markdown]
# **There is no data to drop because all of the values have data. We ran the below code to see the results.**

# %%
# Let's create a function to determine the percentage of missing values
# Typically less than five percent missing values may not affect the results
# More than 5% can be dropped, replaced with existing data, or imputed using mean or median.
# Syntax: def missing(DataFrame):
#    print ('Percentage of missing values in the dataset:\n',
#           round((DataFtame.isnull().sum() * 100/ len(DataFrame)),2).sort_values(ascending=False))

def missing(NatCanRisk):
    print ('Percentage of missing values in the dataset:\n',
           round((NatCanRisk.isnull().sum() * 100/ len(NatCanRisk)),2).sort_values(ascending=False))
# Call the function and execute
# Syntax: missing(DataFrame)

missing(NatCanRisk)
# Out:
# Percentage of missing values in the dataset:
#  State                                                                   0.0
# Solvents Coatings Cancer Risk                                           0.0
# NR-CMV_C1C2_ports Cancer Risk (per million)                             0.0
# NR-CMV_C3_ports Cancer Risk (per million)                               0.0
# NR-CMV_C1C2C3_underway Cancer Risk (per million)                        0.0
# NR-Locomotives Cancer Risk (per million)                                0.0
# NR-Point-Airports Cancer Risk (per million)                             0.0
# NR- Point-Railyards Cancer Risk (per million)                           0.0
# NP-industrial Cancer Risk (per million)                                 0.0
# NP-CommercialCooking Cancer Risk (per million)                          0.0
# NP-OilGas Cancer Risk (per million)                                     0.0
# NP-StorageTransfer_BulkTerminals_GasStage1 Cancer Risk (per million)    0.0
# ...

# %% [markdown]
# ### Observations
# - How many missing values are there?
# - Are these concentrated in specific rows or columns? How does this affect the analysis?
# - Based on the information that is present, how should the missing values be handled? How will this affect the analysis?
#
# **There are no missing values in the dataset. Therefore, the analysis is not affected. **

# %%
# Make a copy of the DataFrame before manipulation
# Syntax: DataFrameOG = workingDF
NanCanRiskOG = NatCanRisk

# %% [markdown]
# **Below I split the dataframe into differnet subsets according to States and County **

# %%
# Let's split the dataframe into subsets as needed.
# Syntax: NewSubsetDF = DataFrame.query('ColumnName == "ValuetoSplit"')


#TotalCancerRiskJeff = NatCanRisk.query('County == "Jefferson"')
#TotalCancerRiskAL = NatCanRisk.query('State == "AL"')
TotalCancerRiskTX =  NatCanRisk.query('State == "TX"')


# Check the new dataframe with .head() method.
#TotalCancerRiskAL.head()
#TotalCancerRiskJeff.head()
TotalCancerRiskTX.head()
# Out:
#       State    EPA Region        County   FIPS        Tract  Population  \
# 63748    TX  Epa Region 6  Entire State  48000  48000000000    25145250
# 63749    TX  Epa Region 6      Anderson  48001  48001000000       58458
# 63750    TX  Epa Region 6      Anderson  48001  48001950100        4685
# 63751    TX  Epa Region 6      Anderson  48001  48001950401        5422
# 63752    TX  Epa Region 6      Anderson  48001  48001950402        7535
#
#        Total Cancer Risk  PT-StationaryPoint Cancer Risk (per million)  \
# 63748                 30                                         4.812
# 63749                 30                                         0.923
# 63750                 30                                         2.160
# 63751                 20                                         0.192
# 63752                 20                                         1.914
#
#        OR-LightDuty-OffNetwork-Gas Cancer Risk (per million)  \
# ...

# %% [markdown]
# **I removed the states with the lowest Total Cancer Risk from the original dataframe. Then, defined the shape and showed the top 10 values. **

# %%
# Let's remove the rows or columns from the original DF
#keep AR, AZ, CA, CO, GA, IL, LA, MO, SC, TX, WV, FL, NJ, NM, TN, VA, PR
# Syntax: DataFrame = DataFrame[DataFrame['ColumnName'] != 'ValuetoSplit']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'AK']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'AL']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'CT']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'DE']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'DC']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'HI']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'ID']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'IN']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'IA']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'KS']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'KY']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'ME']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'MA']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'MI']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'MD']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'MI']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'MN']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'MS']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'MT']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'NE']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'NV']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'NH']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'NY']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'NC']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'ND']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'OH']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'OK']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'OR']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'PA']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'RI']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'SD']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'UT']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'VT']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'WA']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'WI']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'WY']
NatCanRisk = NatCanRisk[NatCanRisk['State'] != 'VI']










# Check the Dataframe shape: DataFrame.shape
NatCanRisk.shape
#NatCanRisk.head(10)
# Out:
# (38278, 46)

# %%
# Let's drop all the NaN values from the new DF
# Syntax: NewSubsetDF = NewSubsetDF.filter(items=['ColumnName1','ColumnName2','ColumnName3'])

NatCanRisk=NatCanRisk.filter(items=['EPA Region','State','County','Total Lawn Garden', 'Population', 'Total Cancer Risk', 'Secondary Cancer Risk', 'Fire Cancer Risk', 'Background Cancer Risk', 'Biogenics Cancer Risk', 'Fuel Combustion not RWC Cancer Risk', 'Residential Wood Combustion'])


# Check the DataFrame again: NewSubsetDF.head()
NatCanRisk.head(10)
# Out:
#         EPA Region State        County  Total Lawn Garden  Population  \
# 0        Entire Us    US     Entire Us              0.418   312566557
# 1444  Epa Region 9    AZ  Entire State              0.276     6391996
# 1445  Epa Region 9    AZ        Apache              0.011       71518
# 1446  Epa Region 9    AZ        Apache              0.005        1578
# 1447  Epa Region 9    AZ        Apache              0.005        5628
# 1448  Epa Region 9    AZ        Apache              0.013        6043
# 1449  Epa Region 9    AZ        Apache              0.004        5870
# 1450  Epa Region 9    AZ        Apache              0.010        4010
# 1451  Epa Region 9    AZ        Apache              0.008        4053
# 1452  Epa Region 9    AZ        Apache              0.005        6958
#
#       Total Cancer Risk  Secondary Cancer Risk  Fire Cancer Risk  \
# 0                    30                 12.709             0.565
# ...

# %%
# Let's create a function to determine the percentage of missing values
# Typically less than five percent missing values may not affect the results
# More than 5% can be dropped, replaced with existing data, or imputed using mean or median.
# Syntax: def missing(DataFrame):
#    print ('Percentage of missing values in the dataset:\n',
#           round((DataFtame.isnull().sum() * 100/ len(DataFrame)),2).sort_values(ascending=False))

def missing(NatCanRisk):
    print ('Percentage of missing values in the dataset:\n',
           round((NatCanRisk.isnull().sum() * 100/ len(NatCanRisk)),2).sort_values(ascending=False))
# Call the function and execute
# Syntax: missing(DataFrame)

missing(NatCanRisk)
# Out:
# Percentage of missing values in the dataset:
#  EPA Region                             0.0
# State                                  0.0
# County                                 0.0
# Total Lawn Garden                      0.0
# Population                             0.0
# Total Cancer Risk                      0.0
# Secondary Cancer Risk                  0.0
# Fire Cancer Risk                       0.0
# Background Cancer Risk                 0.0
# Biogenics Cancer Risk                  0.0
# Fuel Combustion not RWC Cancer Risk    0.0
# Residential Wood Combustion            0.0
# dtype: float64

# %% [markdown]
# ### Observations on Missing Values
# Include observations on the methods used to update the dataFrame for missing values and complete the cleaning process.  Did you use a method to impute the missing data? Did you choose to drop null or NaN values? Did you split the dataset to create subsets? Use this space to explain the techniques, approach, and reasoning.

# %% [markdown]
# **There was no missing data to impute or drop. We did split the data into subsets. We added the .filter method to include the columns that we are going to focus on for the data visualization.  This will help to subset the data and focus on the questions that we are trying to answer about specific States and populations of color, like Counties and demographic data that have the highest rates of cancer. These columns include State, County, Total Cancer Risk, Total Lawn Garden, Secondary Cancer Risk etc. **
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# # Week 4: Data Exploration and Analysis
# This week we will use statistical methods to learn more about the dataset. We can also create visualizations such as charts and graphs to see how the data statistics perform. These charts can be extracted or saved to be placed in reports or executive summaries.

# %% [markdown]
# # Data Exploration:

# %% [markdown]
# ## Summary Statistics

# %% [markdown]
# ##### `.describe()` method
#
# * This method is used to get a summary of numeric values in your dataset.
# * It calculates the mean, standard deviation, minimum value, maximum value, 1st percentile, 2nd percentile, 3rd percentile of the columns with numeric values.
# * It also counts the number of variables in the dataset.

# %%
## describe the descriptive stats - onlyfor numerical data, not strings or objects
# Syntax: DataFrame.describe()

NatCanRisk.describe()

#NatCanRiskMax = NatCanRisk.max()
#NatCanRiskMax

# Note: If we do not pass include=object to the describe(), it would return statistics for numeric variable
# Out:
#        Total Lawn Garden    Population  Total Cancer Risk  \
# count       38278.000000  3.827800e+04       38278.000000
# mean            0.394785  2.101688e+04          26.787789
# std             0.343622  1.623791e+06           9.327617
# min             0.000000  1.000000e+00           7.000000
# 25%             0.118000  3.095000e+03          20.000000
# 50%             0.286000  4.284000e+03          30.000000
# 75%             0.583000  5.739000e+03          30.000000
# max             1.885000  3.125666e+08         400.000000
#
#        Secondary Cancer Risk  Fire Cancer Risk  Background Cancer Risk  \
# count           38278.000000      38278.000000            38278.000000
# mean               13.860373          0.604959                2.983079
# std                 3.418900          0.470498                0.187208
# min                 4.043000          0.000000                2.040000
# 25%                11.496250          0.233000                3.000000
# ...

# %% [markdown]
# I have different subsets listed below. One of the subsets include the entire state of TX. The other subsets are counties in TX that had some of the highest total cancer rates -Jefferson County and El Paso, and lowest cancer rates- Rockwall and Collin. I will then compare

# %%
## Descriptive stats for subset DataFrame
#TotalLawnGardenHI = NatCanRisk.query('TotalLawnGarden > 1')
#TotalLawnGardenHI.describe()

##TotalCancerRiskTX = NatCanRisk.query('State == "TX"')
##TotalCancerRiskTX.describe()
#maxValuesTX = TotalCancerRiskTX.max()
#maxValuesTX
#minValuesTX = TotalCancerRiskTX.min()
#minValuesTX

TxJefferson = NatCanRisk.query('County == "Jefferson"')
TxJefferson.describe()


## compare the demo of the high and low counties.
# Out:
#        Total Lawn Garden     Population  Total Cancer Risk  \
# count         451.000000     451.000000         451.000000
# mean            0.462623    7498.447894          32.483370
# std             0.475139   35902.374705          19.551563
# min             0.031000      85.000000          10.000000
# 25%             0.088000    2720.000000          30.000000
# 50%             0.235000    3703.000000          30.000000
# 75%             0.867000    4956.000000          30.000000
# max             1.471000  534543.000000         200.000000
#
#        Secondary Cancer Risk  Fire Cancer Risk  Background Cancer Risk  \
# count             451.000000        451.000000              451.000000
# mean               13.410129          0.657257                2.909867
# std                 3.753684          0.362819                0.231018
# min                 5.210000          0.176000                2.350000
# 25%                 8.768000          0.224000                2.580000
# ...

# %%
TotalCancerRiskTX = NatCanRisk.query('State == "TX"')
TotalCancerRiskTX.describe()
# Out:
#        Total Lawn Garden    Population  Total Cancer Risk  \
# count        5493.000000  5.493000e+03        5493.000000
# mean            0.154722  1.373307e+04          27.360277
# std             0.102890  3.480761e+05          12.486876
# min             0.000000  2.000000e+00          10.000000
# 25%             0.060000  3.222000e+03          20.000000
# 50%             0.150000  4.518000e+03          30.000000
# 75%             0.236000  6.186000e+03          30.000000
# max             0.396000  2.514525e+07         400.000000
#
#        Secondary Cancer Risk  Fire Cancer Risk  Background Cancer Risk  \
# count            5493.000000       5493.000000             5493.000000
# mean               13.890227          0.689753                2.969478
# std                 2.150016          0.313792                0.084766
# min                 7.188000          0.079000                2.577000
# 25%                12.430000          0.438000                2.975000
# ...

# %%
TxElPaso = NatCanRisk.query('County == "El Paso"')
TxElPaso.describe()
# Out:
#        Total Lawn Garden     Population  Total Cancer Risk  \
# count         293.000000     293.000000         293.000000
# mean            0.278352    9712.682594          30.034130
# std             0.181104   58777.130932          33.764883
# min             0.006000       2.000000          10.000000
# 25%             0.144000    3548.000000          20.000000
# 50%             0.208000    4693.000000          20.000000
# 75%             0.401000    6182.000000          40.000000
# max             0.690000  800647.000000         400.000000
#
#        Secondary Cancer Risk  Fire Cancer Risk  Background Cancer Risk  \
# count             293.000000        293.000000              293.000000
# mean                8.700621          0.133823                2.598474
# std                 2.086803          0.051919                0.106568
# min                 5.311000          0.080000                2.362000
# 25%                 6.682000          0.087000                2.520000
# ...

# %%
TxRockwall = NatCanRisk.query('County == "Rockwall"')
TxRockwall.describe()
# Out:
#        Total Lawn Garden    Population  Total Cancer Risk  \
# count          12.000000     12.000000          12.000000
# mean            0.176333  13056.166667          24.166667
# std             0.038104  20622.800065           5.149287
# min             0.113000   4430.000000          20.000000
# 25%             0.156500   6241.250000          20.000000
# 50%             0.175000   6788.500000          20.000000
# 75%             0.193750   9120.500000          30.000000
# max             0.256000  78337.000000          30.000000
#
#        Secondary Cancer Risk  Fire Cancer Risk  Background Cancer Risk  \
# count              12.000000         12.000000                    12.0
# mean               14.472000          0.866667                     3.0
# std                 0.406542          0.023562                     0.0
# min                14.248000          0.834000                     3.0
# 25%                14.284500          0.855250                     3.0
# ...

# %%
TxCollin = NatCanRisk.query('County == "Collin"')
TxCollin.describe()
# Out:
#        Total Lawn Garden     Population  Total Cancer Risk  \
# count         153.000000     153.000000         153.000000
# mean            0.290902   10226.679739          28.496732
# std             0.053953   62889.705061           3.585652
# min             0.096000    1268.000000          20.000000
# 25%             0.273000    3371.000000          30.000000
# 50%             0.309000    4642.000000          30.000000
# 75%             0.327000    6293.000000          30.000000
# max             0.349000  782341.000000          30.000000
#
#        Secondary Cancer Risk  Fire Cancer Risk  Background Cancer Risk  \
# count             153.000000        153.000000                   153.0
# mean               15.807935          0.817150                     3.0
# std                 0.694774          0.021752                     0.0
# min                14.022000          0.797000                     3.0
# 25%                15.642000          0.803000                     3.0
# ...

# %% [markdown]
# #### Observations of Descriptive Statistics
# The following are some observations about each table: <br>
# DataFrame:
#
# NatCanRisk.describe()
#
#  * What are the minimum and maximum values?
#
# **
#
# **The max total lawn garden per million is 1.885000. The max total cancer per million is 400. The max secondary risk is 26.04. The max Fire risk per million is 8.276. The max Background cancer risk per million is 3.18. The max Biogenics cancer risk per million is 8.92. The max of Fuel Combustion is 1.575. The max of Residential wood combustion is 15.17**
#
# **The min total lawn garden per million is 0.00. The min total cancer per million is 7. The min secondary risk is 4.043. The min Fire risk per million is 0.000000. The min Background cancer risk per million is 2.04. The min Biogenics cancer risk per million is 0.022. The min of Fuel Combustion is 0. The min of Residential wood combustion is 0.** **
#
#   * What are the mean values for the data?
#
# **The mean total lawn garden per million is 0.394785. The mean total cancer per million is 26.787789. The mean secondary risk is 13.860373. The mean Fire risk per million is 0.604959. The mean Background cancer risk per million is 2.983079. The mean Biogenics cancer risk per million is 2.247266. The mean value of Fuel Combustion is 0.083273. The mean value of Residential wood combustion is 0.997 **
#
#  * Are the mean and median values close to each other? If so this could indicate a normal distribution of the data. If not, this could indicate skewness in the data. If the mean is smaller than the median the values are likely skewed left, toward the minimum value. If the mean is larger than the median then there is skewness to the right indicating more high values in the data distribution.
#
# **Yes, the median and mean values are close to each other. **
#
#  * What are the quartile ranges for the data? What value is the 25th percentile of the data? What value is the 75th percentile of the data?
#
# **The 25th percentile of total lawn garden per million is 0.118000; the 75th percentile is 0.583000. The 25th percentile of total cancer per million is 20; the 75th percentile is 30. The 25th percentile of secondary risk is 11.496250; the 75th percentile is 15.9540. The 25th percentile of Fire risk per million is 0.233; the 75th percentile is 0.849. The 25th percentile of Background cancer risk per million is 2.983079; the 75th percentile is 3.06. The 25th percentile of Biogenics cancer risk per million is 3; the 75th percentile is 5.703. The 25th percentile for Fuel combustion is 0.015 and the 75th percentile is 0.1. The 25th percentile for Residential Wood Combustion is 0.314 and the 75th pecercentile is 1.305. **
#
#  * How does the standard deviation for the data compare to the mean? High values for the standard deviation indicate a large variation in the data and likely a wide spread of the data across the range from minimum to maximum.
#
#
# ** There are high values for the standard deviation in the dataset. There are large jumps between some of the values in the dataset, especially  in Total Cancer Risk per million - mean 26.79 and std 9.33. This is also reflected in the max and min -max 400 and min 7.  **
#
#
#  <br>
#
# Dataframe Subset:
#
# TotalCancerRiskTX = NatCanRisk.query('State == "TX"')
# TotalCancerRiskTX.describe()
#
#
# * Consider the same questions above.
# **The max total lawn garden per million is 0.396. The max total cancer per million is 400. The max secondary cancer risk is 20.247. The max Fire risk per million is 5.513. The max Background cancer risk per million is 3.06. The max Biogenics cancer risk per million is 5.703.  The max of Fuel Combustion is 1.356. The max of Residential wood combustion is 0.798. **
#
# **The min total lawn garden per million is 0.00. The min total cancer per million is 10. The min secondary risk is 7.188. The min Fire cancer risk per million is 0.079. The min Background cancer risk per million is 2.577. The min Biogenics cancer risk per million is 0.133.  The min of Fuel Combustion is 0.002. The min of Residential wood combustion is 0.002.**
#
# **The median and mean values are close to each other with this subset. **
#
# **The 25th percentile of total lawn garden per million is 0.06; the 75th percentile is 0.236. The 25th percentile of total cancer per million is 20; the 75th percentile is 30. The 25th percentile of secondary cancer risk is 12.43; the 75th percentile is 15.664. The 25th percentile of Fire cancer risk per million is 0.438; the 75th percentile is 0.828. The 25th percentile of Background cancer risk per million is 2.975; the 75th percentile is 0.174. The 25th percentile of Biogenics cancer risk per million is 1.78; the 75th percentile is 2.084. The 25th percentile for Fuel combustion is 0.057 and the 75th percentile is 0.169. The 25th percentile for Residential Wood Combustion is 0.127 and the 75th pecercentile is 0.271. **
#
#
# ** There are high values for the standard deviation in the dataset. There are large jumps between some of the values in the dataset, especially  in Total Cancer Risk per million - mean 27.36 and std 12.49. This is also reflected in the max and min -max 400 and min 10.  **

# %% [markdown]
# ### Correlation

# %% [markdown]
# * Correlation is a statistic that measures the degree to which two variables move in relation to each other. A positive correlation indicates
# * the extent to which those variables increase or decrease in parallel; a negative correlation indicates the extent to which one variable
# * increases as the other decreases. Correction among multiple variables can be represented in the form of a matrix. This allows us to see which pairs have the high correlations.
# * correlation Correlation is a mutual relationship or connection between two or more things. It takes a value between (+1) and (-1)
# * One important note here; Correlation can be created between integer values, so columns come with string values will not be included.

# %%
#TxJeffersoncorr=TxJefferson.corr(numeric_only=True)
#TxJeffersoncorr

# %%
# Create correlation matrix
# Syntax: variableCorr = DataFrame.corr()




TxJeffersoncorr=TxJefferson.corr(numeric_only=True)
TxJeffersoncorr



# Now call the correlation variable to see the correlation matrix.  yellow hot spots ; negative corr check these
# Out:
#                                      Total Lawn Garden  Population  \
# Total Lawn Garden                             1.000000    0.007277
# Population                                    0.007277    1.000000
# Total Cancer Risk                            -0.190535    0.000341
# Secondary Cancer Risk                        -0.779802   -0.006564
# Fire Cancer Risk                             -0.773407   -0.005221
# Background Cancer Risk                       -0.852411   -0.004764
# Biogenics Cancer Risk                        -0.688790   -0.001324
# Fuel Combustion not RWC Cancer Risk          -0.398953   -0.009795
# Residential Wood Combustion                   0.749833    0.014344
#
#                                      Total Cancer Risk  Secondary Cancer Risk  \
# Total Lawn Garden                            -0.190535              -0.779802
# Population                                    0.000341              -0.006564
# ...

# %%
TotalCancerRiskTXCorr=TotalCancerRiskTX.corr(numeric_only=True)
TotalCancerRiskTXCorr
# Out:
#                                      Total Lawn Garden  Population  \
# Total Lawn Garden                             1.000000    0.003574
# Population                                    0.003574    1.000000
# Total Cancer Risk                             0.217260    0.004191
# Secondary Cancer Risk                         0.520535    0.003211
# Fire Cancer Risk                              0.095564    0.001324
# Background Cancer Risk                        0.153828    0.002674
# Biogenics Cancer Risk                        -0.255126    0.000742
# Fuel Combustion not RWC Cancer Risk           0.123065    0.000793
# Residential Wood Combustion                   0.728514    0.004649
#
#                                      Total Cancer Risk  Secondary Cancer Risk  \
# Total Lawn Garden                             0.217260               0.520535
# Population                                    0.004191               0.003211
# ...

# %%
TxRockwallCorr=TotalCancerRiskTX.corr(numeric_only=True)
TxRockwallCorr
# Out:
#                                      Total Lawn Garden  Population  \
# Total Lawn Garden                             1.000000    0.003574
# Population                                    0.003574    1.000000
# Total Cancer Risk                             0.217260    0.004191
# Secondary Cancer Risk                         0.520535    0.003211
# Fire Cancer Risk                              0.095564    0.001324
# Background Cancer Risk                        0.153828    0.002674
# Biogenics Cancer Risk                        -0.255126    0.000742
# Fuel Combustion not RWC Cancer Risk           0.123065    0.000793
# Residential Wood Combustion                   0.728514    0.004649
#
#                                      Total Cancer Risk  Secondary Cancer Risk  \
# Total Lawn Garden                             0.217260               0.520535
# Population                                    0.004191               0.003211
# ...

# %%
# Set seaborn themes
sns.set_theme(style='white')
sns.color_palette('magma', as_cmap=True)

# %%
# To get a correlation matrix
# Ploting the heat map
# corr: give the correlation matrix
# cmap: color code used for plotting
# vmax: gives maximum range of values for the chart
# vmin: gives minimum range of values for the chart
# annot: prints the correlation values in the chart
# annot_kws={"size": 12}): Sets the font size of the annotation

# Create the plot
plt.figure(figsize=(10,6))
matrix = TxJeffersoncorr
mask = np.triu(np.ones_like(matrix, dtype=float))
sns.heatmap(TxJeffersoncorr,
            annot=True,
            linewidths=.5,
            cmap='viridis',
            fmt= '.2f',
            mask=mask)

# specify name of the plot
plt.title('Correlation Between Features in Jefferson County, TX')
plt.show()

# %% [markdown]
# https://datausa.io/profile/geo/jefferson-county-tx?redirect=true#health
#
# 2022
# The poverty rate is 18.2%.
# The household median income is $57,294
# The median property price is $151, 500
# Race: White 38.4%, Black 33%, White hispanic 9%
# The number of uninsured people are 20.8%.
# The number of people Medicaid is 17.3%.
# The number of people with Employer Based health coverage is 39.4%

# %%
# To get a correlation matrix
# Ploting the heat map
# corr: give the correlation matrix
# cmap: color code used for plotting
# vmax: gives maximum range of values for the chart
# vmin: gives minimum range of values for the chart
# annot: prints the correlation values in the chart
# annot_kws={"size": 12}): Sets the font size of the annotation

# Create the plot
plt.figure(figsize=(10,6))
matrix = TotalCancerRiskTXCorr
mask = np.triu(np.ones_like(matrix, dtype=float))
sns.heatmap(TotalCancerRiskTXCorr,
            annot=True,
            linewidths=.5,
            cmap='viridis',
            fmt= '.2f',
            mask=mask)

# specify name of the plot
plt.title('Correlation Between Features in the state of TX')
plt.show()

# %%
# To get a correlation matrix
# Ploting the heat map
# corr: give the correlation matrix
# cmap: color code used for plotting
# vmax: gives maximum range of values for the chart
# vmin: gives minimum range of values for the chart
# annot: prints the correlation values in the chart
# annot_kws={"size": 12}): Sets the font size of the annotation

# Create the plot
plt.figure(figsize=(10,6))
matrix = TxRockwallCorr
mask = np.triu(np.ones_like(matrix, dtype=float))
sns.heatmap(TxRockwallCorr,
            annot=True,
            linewidths=.5,
            cmap='viridis',
            fmt= '.2f',
            mask=mask)

# specify name of the plot
plt.title('Correlation Between Features in Rockwall County, TX')
plt.show()

# %% [markdown]
# https://datausa.io/profile/geo/rockwall-county-tx#health
# 2022
# The poverty rate is 4.17%.
# The household median income is $121,303
# The median property price is $363,500
# Race: White 66.7%, Black 7.5%, White hispanic 8%
# The number of uninsured people are 8.72%.
# The number of people Medicaid is 6.4%.
# The number of people with Employer Based health coverage is 62%

# %% [markdown]
# ### Observations
# - Are all the values the same color? This is called multicolinearity and indicates there are multiple independent variables that each have a strong relationship on each other. For instance if you are examining crime data categories such as robbery may also correlate to vehicular theft as the assailant was charged with both crimes. While they are independent crimes, they often occur together indicating a relationship. Multicolinear relationships complicate feature engineering for machine learning models and may need to have their dimensionality reduced (dropping columns or further subsets) to make sure the model trains well for those specific variables.
#
# **The values are not the same colors. There are values that are yellow, green, purple, and blue. **
#
# - Are specific variables correlated higher than others?
#
# **There are specific variables correlated higher than others. In the Jefferson County chart, secondary, background, fire, and biogenics are all highly positively correlated, shown in yellow. All of the TX charts show a high positive correlation between total lawn garden and residential wood combustion.**
#
#
# - Are there negative correlations indicating an inverse relationship in the variables? This indicates that as one variable is increasing, the other variable is decreasing. Negative correlations can be high (close to -1) or low (close to 0).
#
#
# **In Jefferson County, the Secondary, background, fire, biogenics and total lawn garden have a high negative correlation, shown in purple. **
#
#
# - Remember that correlation does not equal causation. Be careful with your wording when establishing relationships between the variables.
# - Are there variables that lack correlation to any other variable? These are variables that may not be needed in the analysis and can be used to reduce the dimensionality of the data.
#
# **Surprisingly, population does not appear to have an effect on the other variables, shown by the values 0.00 and 0.01. This could be caused by singling out a single state and county instead of looking at the data for the nation.**

# %% [markdown]
# Additional Statistical methods are possible. Python is a mathematical programming language and can perform inferential statistics, hypothesis testing, probability distributions, and multivariate statistical analysis.

# %% [markdown]
# ## Visualizations
# Create Visualizations to aid in the interpretation of the data and answering of the research problem. Using Python plotting libraries seaborn, matplotlib, plotly, or bokeh multiple plots will be completed to see trends and insights in the data.
#   - Use charts, graphs, maps, and other plots to answer questions related to your research question.
#   - Bivariate analysis is the process of examing two variables to visualize their relationship. Choose variables from the correlation matrix to see how they affect each other.
#   - Be sure to use the correct chart for the type of information you need.

# %%
# Group data by variable1 and calculate the average percentage of variable2 for each variable1
# Syntax: averageVariable1 = DataFrame.groupby('variable1')['variable2'].mean()

averageVariable1 = TxJeffersoncorr.groupby('Background Cancer Risk')['Secondary Cancer Risk'].mean()

# Sort variable1 based on the highest average percentage of variable2
# Syntax: maxVariable1 = averageVariable1.sort_values(ascending=False).head(50)

maxVariable1 = averageVariable1.sort_values(ascending=False).head(50)

# Create a scatter plot
plt.figure(figsize=(12, 6))
plt.scatter(maxVariable1.index, maxVariable1.values)

# Describe the axes
plt.xlabel('Background Cancer Risk')
plt.ylabel('Secondary Cancer Risk')

# Define the titlex
plt.title('Background Cancer Risk with Highest Average Percentage of Secondary Cancer Risk In Jefferson County TX')

# Rotate the x-axis labels
plt.xticks(rotation=90)

# Complete the plot
plt.grid(axis='y')
plt.tight_layout()

# Show the visualization
plt.show()

# %% [markdown]
# ### Observations: Scatter Plot
# Each visualization should have a summary of the findings.

# %%
# Set Plotly themes
# Javascript Interactive Visualization (computationally expensive)
import plotly.express as px
import plotly.io as pio
pio.templates.default = 'plotly_white'

# %%
# Create an averages table
#variable_avg = DataFrame.groupby('Variable').mean().sort_values(by='sortingVariable',ascending=False)
#variable_avg

# Create visualization: Bar chart
#fig = px.bar(variable_avg,
#             x="State Population",
#             y=variable_avg.index,
#             color=variable_avg.index,
#             orientation='h',
#             height=1000,
#             title='Plot Title')

# View the plot
#fig.show()

# %%
# Create an averages table
variable_avg = TxJeffersoncorr.groupby('Fire Cancer Risk').mean().sort_values(by='Background Cancer Risk',ascending=False)
variable_avg

# Create visualization: Bar chart
fig = px.bar(variable_avg,
             x="Background Cancer Risk",
             y=variable_avg.index,
             color=variable_avg.index,
             orientation='h',
             height=1000,
             title='Jefferson County Fire Cancer Risk by Background')

# View the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Observations: Bar Chart
# Each visualization should have a summary of the findings.

# %% [markdown]
#  ### Research Question: Insert Primary Research Question Here
# Explain how the technique this visualization uses describes the research question.

# %%
# Create visualization: Plotly Scatter chart
#fig  = px.scatter(DataFrame,x='VariableName',
#                  y = 'VariableName2',
#                  title = 'Average VariableName versus Average VariableName2 by Hue',
#                  color = VariableVariationByColor.index)
#fig.show()

# %%
# Create visualization: Plotly Scatter chart
fig  = px.scatter(TxJeffersoncorr,x='Secondary Cancer Risk',
                  y = 'Total Lawn Garden',
                  title = 'In Jefferson County TX -Average Secondary Cancer Risk versus Average Total Lawn Risk by Residential Wood Combustion',
                  color = 'Residential Wood Combustion')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create visualization: Plotly Scatter
fig  = px.scatter(TxJeffersoncorr,x='Biogenics Cancer Risk',
                  y = 'Secondary Cancer Risk',
                  title = 'Jefferson County TX- Average Biogenics Cancer Risk versus Average Secondary Cancer Risk by Total Cancer Risk',
                  color = 'Total Cancer Risk')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Fuel Combustion not RWC Cancer Risk

# %%
# Create visualization: Plotly Scatter chart
fig  = px.scatter(NatCanRisk,x='Secondary Cancer Risk',
                  y = 'Total Cancer Risk',
                  title = 'National Average Secondary Cancer Risk versus Average Total Cancer Risk by Popluation',
                  color = 'Population')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# There does not appear to be a correlation between population and cancer risk across the nation.

# %% [markdown]
# #### Observations
# Each visualization should have a summary of the findings.

# %% [markdown]
# ### Research Question: Insert Secondary Research Question Here
# Explain how the technique this visualization uses describes the research question.

# %%
# Create visualization: Plotly Line chart
fig = px.line(NatCanRisk, x="Total Cancer Risk",
              y="Secondary Cancer Risk",
              color="EPA Region",
              title='National Cancer Risk vs Secondary Cancer Risk by EPA region ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create visualization: Plotly Line chart
fig = px.line(NatCanRisk, x="Total Cancer Risk",
              y="Background Cancer Risk",
              color="State",
              title='National Cancer Risk vs Background Cancer Risk by State ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create visualization: Plotly Line chart
fig = px.line(NatCanRisk, x="Secondary Cancer Risk",
              y="Background Cancer Risk",
              color="State",
              title='National Secondary Cancer Risk vs Background Cancer Risk by State ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The highest correlation of Background and Secondary cancer risk in SC, GA, and VA.

# %% [markdown]
# #### Observations
# From this visualization, we observe the following:
#   - Observations from your visualization should be described here.

# %% [markdown]
# ### Research Question: Insert Tertiary Research Question Here
# Explain how the technique this visualization uses describes the research question.

# %%
# Create visualization: Plotly Pie chart
#fig = px.pie(DataFrame, values= 'Variable1',
#             names=DataFrame.index,
#             height=1000,
#             title='Chart Title')
#fig.show()

# Create visualization: Plotly Pie chart
fig = px.pie(TxJeffersoncorr, values= 'Total Cancer Risk',
             names=TxJeffersoncorr.index,
             height=1000,
             title='Total Cancer Risk Jefferson county TX')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The Total Cancer risk in Jefferson county is 48.8%.
#
# The Total Cancer risk in Rockwall county is 39.9%.

# %%
# Create visualization: Plotly Pie chart
fig = px.pie(TxRockwallCorr, values= 'Total Cancer Risk',
             names=TxRockwallCorr.index,
             height=1000,
             title='Total Cancer Risk Rockwall county TX')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
